# %% [markdown]
# # Supabase 연동하기

# %%
import os
from supabase import create_client

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_PUBLISHABLE_KEY")

# supabase 클라이언트 객체 생성
supabase = create_client(url, key)

print(supabase)
# Out:
# <supabase._sync.client.Client object at 0x0000016CF2435D30>

# %%
from dotenv import load_dotenv

# .env 파일의 환경 변수를 불러온다.
load_dotenv()

num1 = os.getenv("CONFIG_NUM1")
str1 = os.getenv("CONFIG_STR")

print(num1, str1)
# Out:
# 100 ABC
