# %% [markdown]
# ## 3장 1강 : Zero-shot 프롬프팅

# %% [markdown]
# ### 3. Zero-shot 프롬프트 설계 및 실행 실습

# %% [markdown]
# #### 3.1 명확한 기준을 제시한 리뷰 분류기

# %% [markdown]
# 판단 기준과 출력 제약 조건을 엄격하게 정의한 프롬프트입니다.

# %% [markdown]
# #### 3.2 제약 조건을 적용한 고객 피드백 요약

# %% [markdown]
# 출력 분량과 문체를 제어하는 Zero-shot 요약 프롬프트입니다.

# %% [markdown]
# ### 4. Zero-shot의 한계와 실패 사례

# %% [markdown]
# ### 4.2 실패 및 포맷 불일치 재현 실습
