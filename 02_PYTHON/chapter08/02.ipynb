# %% [markdown]
# ## 8장 2강 : 상속과 캡슐화

# %% [markdown]
# ### 1. 상속(Inheritance)

# %% [markdown]
# - 클래스 기반의 상속(상속에 대한 정의 -> 객체 생성(상속 관계 성립))
#
# ```
# class 자식클래스(부모클래스):
#     ...
# ```
#
# - super: 부모 클래스를 가리키는 참조 변수
#  - 참고) self: 자식 객체(현재 객체)의 참조 변수
#  - super() : 부모쪽 객체 생성
#
#
# - 부모클래스 : 일반적인 정의들, 상위 개념
# - 자식클래스 : 구제적인 정의들, 하위 개념

# %%
class Animal:

    def __init__(self, kind):
        self.kind = kind # 동물 종류

    def move(self):
        print("동물이 움직인다.")


class Dog(Animal):
    def __init__(self):
        super().__init__("강아지") # 부모쪽 인스턴스 변수인 kind에 초기화
    
    

class Cat(Animal):
    def __init__(self):
        super().__init__("고양이")

# %%
dog = Dog()
dog.move()

cat = Cat()
cat.move()
# Out:
# 동물이 움직인다.
# 동물이 움직인다.

# %%
print(dog.kind, cat.kind)
# Out:
# 강아지 고양이

# %% [markdown]
# ### 2. 메서드 오버라이딩(Overriding)

# %% [markdown]
# - 메서드 재정의
# - 부모쪽 클래스와 동일한 이름으로 정의하여 기능을 수정, 재정의
# - 자식쪽 클래스에 정의된 동일한 이름의 함수가 호출 우선순위를 가진다.
# - 자식쪽에서 부모쪽 동일한 이름의 메서드를 호출해야하는 경우는 self로 접근 X
#     - super().부모쪽 메서드(..)

# %%
class Animal:

    def __init__(self, kind):
        self.kind = kind # 동물 종류

    def move(self):
        print("동물이 움직인다.")


class Dog(Animal):
    def __init__(self):
        super().__init__("강아지") # 부모쪽 인스턴스 변수인 kind에 초기화
    
    def move(self):
        super().move() # 부모쪽 객체의 move()
        print(self.kind + " 걸음으로 움직인다.")
    

class Cat(Animal):
    def __init__(self):
        super().__init__("고양이")

    def move(self):
        print(self.kind + "걸음으로 움직인다.")

# %%
dog = Dog()
dog.move()

cat = Cat()
cat.move()
# Out:
# 동물이 움직인다.
# 강아지 걸음으로 움직인다.
# 고양이걸음으로 움직인다.

# %%
class Human:
    def move(self):
        print("두발로 직립보행한다.")

# %%
human = Human()
human.move()
# Out:
# 두발로 직립보행한다.

# %% [markdown]
# #### 객체의 출처(클래스 자료형) 확인하는 함수 - isinstance(참조 변수, 클래스/자료형)

# %%
print("Human은 Animal 클래스로 부터 생성되었나?", isinstance(human, Animal))
print("Human은 Human 클래스로 부터 생성되었나?", isinstance(human, Human))

print("Dog은 Animal 클래스로 부터 생성되었나?", isinstance(dog, Animal))
# Out:
# Human은 Animal 클래스로 부터 생성되었나? False
# Human은 Human 클래스로 부터 생성되었나? True
# Dog은 Animal 클래스로 부터 생성되었나? True

# %%
s = "ABC"
#s.lower()
# 문자열인지 체크
isinstance(s, str)
# Out:
# True

# %% [markdown]
# #### 다중 상속 - 여러 부모클래스를 상속 관계로 정의 가능

# %% [markdown]
# - 다중 상속시 같은 메서드가 있을 때 호출 우선 순위(MRO)
# - 자식 클래스의 메서드 -> 상속 관계에서 왼쪽에 있는 클래스 ->

# %%
class ParentA:
    def a(self):
        print("ParentA - a()")

    def b(self):
        print("ParentA - b()")

class ParentB:
    def a(self):
        print("ParentB - a()")

    def c(self):
        print("ParentB - c()")

class Child(ParentA,ParentB):
    pass

# class Child(ParentB,ParentA):
#     pass

# %%
c = Child()
c.b()
c.c()
c.a()
# Out:
# ParentA - b()
# ParentB - c()
# ParentA - a()

# %%
Child.__mro__ # Method Resolution Order - 메서드 우순순위
# Out:
# (__main__.Child, __main__.ParentB, __main__.ParentA, object)

# %% [markdown]
# ### 3. 부모 클래스를 호출하는 super()

# %% [markdown]
# ### 4. 정보 은닉과 캡슐화(Encapsulation)

# %%
class Schedule:
    def __init__(self, year, month, day):
        self.year = year
        self.month = month
        self.day = day

    def __str__(self):
        return f"year={self.year}, month={self.month}, day={self.day}"

# %%
s1 = Schedule(2026,8,18)

print(s1)
# Out:
# year=2026, month=8, day=18

# %%
# 인스턴스 변수에 직접 대입이 가능하므로 값에 대한 통제는 불가!
# 통제 불가능하면 -> 직접 접근을 막아야 한다! -> 인스턴스 변수를 외부에서 접근하지 못하게 막는다.
s1.year = 2026
s1.month = 2
s1.day = 31

print(s1)
# Out:
# year=2026, month=2, day=31

# %% [markdown]
# ### 5. 파이썬 프라이빗(Private) 변수와 이름 변형 규칙(Name Mangling)

# %% [markdown]
# - \_\_변수명: 클래스 내부에서만 접근 가능한 인스턴수 변수가 된다.

# %%
class Schedule:
    def __init__(self, year, month, day):
        self.__year = year
        self.__month = month
        self.__day = day

    def __str__(self):
        return f"year={self.__year}, month={self.__month}, day={self.__day}"

# %%
s1 = Schedule(2026, 8, 18)

print(s1)
# Out:
# year=2026, month=8, day=18

# %%
s1.__year = 2026
s1.__month = 2
s1.__day = 31

print(s1)
# Out:
# year=2026, month=8, day=18

# %% [markdown]
# ### 6. Getter와 Setter 메서드

# %%
class Schedule:
    def __init__(self, year, month, day):
        self.__year = year
        self.__month = month
        self.__day = day

    def get_year(self):
        return self.__year

    def get_month(self):
        return self.__month

    def get_day(self):
        return self.__day


    def set_year(self, year):
        self.__year = year

    def set_month(self, month):
        self.__month = month

    def set_day(self, day):
        if self.__month == 2 and day > 28:  # 값에대한 통제가 가능
            day = 28
        
        self.__day = day

    def __str__(self):
        return f"year={self.__year}, month={self.__month}, day={self.__day}"

# %%
s1 = Schedule(2026, 8, 18)

s1.set_month(2)
s1.set_day(31)

print(s1)
# Out:
# year=2026, month=2, day=28
