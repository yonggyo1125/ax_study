# %% [markdown]
# ## 4장 1강 : 조건문

# %% [markdown]
# ### 1. 단일 조건문: if

# %% [markdown]
# ### 2. if-else 조건문

# %% [markdown]
# ### 3. 다중 조건 분기: if-elif-else

# %% [markdown]
# ### 4. 복잡한 조건 처리: 중첩 조건문과 논리 연산자 결합
