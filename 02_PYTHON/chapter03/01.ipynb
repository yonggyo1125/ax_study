# %% [markdown]
# ## 3장 1강 : 시퀀스 자료구조

# %% [markdown]
# ### 1. 문자열(str)

# %% [markdown]
# ### 2. 리스트(List)

# %% [markdown]
# ### 3. 튜플(Tuple)

# %% [markdown]
# ### 4. 인덱싱(Indexing)

# %% [markdown]
# ### 5. 슬라이싱(Slicing)

# %% [markdown]
# ### 6. 시퀀스 자료구조 연산

# %% [markdown]
# ### 7. 패킹(Packing)과 언패킹(Unpacking)
