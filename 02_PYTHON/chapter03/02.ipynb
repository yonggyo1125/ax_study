# %% [markdown]
# ## 3장 2강 : 매핑 및 집합 자료구조

# %% [markdown]
# ### 1. 딕셔너리(Dictionary) 자료구조

# %% [markdown]
# ### 2. 딕셔너리의 고급 제어

# %% [markdown]
# ### 3. 집합(Set) 자료구조

# %% [markdown]
# ### 4. 자료구조 간의 상호 변환과 데이터 정제
