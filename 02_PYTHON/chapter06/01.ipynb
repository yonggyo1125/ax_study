# %% [markdown]
# ## 6장 1강 : 모듈과 패키지

# %% [markdown]
# ### 1. 독립 소스 파일 모듈(Module)

# %% [markdown]
# ### 2. 디렉터리형 패키지(Package)

# %% [markdown]
# ### 3. import, from, as 키워드

# %% [markdown]
# ### 4. 파이썬 표준 라이브러리

# %% [markdown]
# ### 5. 사용자 정의 모듈 분리 및 별칭 호출 구현

# %% [markdown]
# ### 6. random

# %% [markdown]
# ### 7. datetime 포맷팅
