# %% [markdown]
# ## 10장 1강 : 파일 입출력과 구조화된 데이터 변환

# %% [markdown]
# ### 1. with open()의 자원 자동 해제

# %% [markdown]
# ### 2. 텍스트 파일 읽기 함수(read, readline, readlines)

# %% [markdown]
# ### 3. CSV 형식

# %% [markdown]
# ### 4. JSON 형식
