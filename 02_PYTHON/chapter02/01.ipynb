# %%
x = 5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 2359650866800

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 2359650866800

# %%
x = 500
id(x)
# Out:
# 2359650867632

# %%
x = 600
id(x)
# Out:
# 2359650863568

# %%
x = 500
id(x)
# Out:
# 2359650866224

# %%
a = 10
id(a)
# Out:
# 140730836128968

# %%
a = 20
id(a)
# Out:
# 140730836129288

# %%
a = 10
id(a)
# Out:
# 140730836128968

# %%
number_of_student = 100

# %%
type(number_of_student)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
result = True
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
