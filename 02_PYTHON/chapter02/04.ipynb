# %% [markdown]
# ## 2장 4강 : 문자열 형식화

# %% [markdown]
# ### 1. 1세대: % 연산자 방식

# %% [markdown]
# - %s: 문자열 대체
#     - %숫자s -> 최소 숫자 자리수 만큼 공간을 차지, 남는 공간은 공백
#
# - %d: 정수
#     - %대체문자슷자d -> %05d -> 남는 공백은 0으로 대체
#
# - %f: 실수
#     - %.2f : 소수점 2자리까지 표시
#     - %10.2f: 정수부 8자리, 소수점 자리는 2

# %%
message = "나의 이름은 %10s이고, 나이는 %d입니다."

message % ("철수", 20)
# Out:
# '나의 이름은         철수이고, 나이는 20입니다.'

# %%
message = "주문번호: %05d" % 10
message
# Out:
# '주문번호: 00010'

# %%
# message = "숫자: %f" % 10.123456789
# message = "숫자: %.2f" % 10.123456789
# message = "숫자: %10.2f" % 10.123456789
message = "숫자: %010.2f" % 10.123456789
message
# Out:
# '숫자: 0000010.12'

# %%
message = "숫자: %d" % 10.12345
message
# Out:
# '숫자: 10'

# %%
message = "숫자: %s" % 10.12345
message
# Out:
# '숫자: 10.12345'

# %% [markdown]
# ### 2. 2세대: str.format() 메서드 방식

# %% [markdown]
# ### 3. 3세대: f-string 방식
