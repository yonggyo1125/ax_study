# %% [markdown]
# ## 9장 2강 : 표준 라이브러리

# %% [markdown]
# ### 1. [날짜와 시간] datetime & time

# %% [markdown]
# ### 2. [수학 연산] math

# %% [markdown]
# ### 3. [데이터 표준 변환] json

# %% [markdown]
# ### 4. [무작위 난수 추출] random

# %% [markdown]
# ### 5. [시스템 및 파일 제어] os & sys
