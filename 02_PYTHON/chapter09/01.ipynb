# %% [markdown]
# ## 9장 1강 : 내장 함수

# %% [markdown]
# ### 1. isinstance() : 자료형 검증

# %% [markdown]
# ### 2. all()과 any()

# %% [markdown]
# ### 3. len(), sum(), round()

# %% [markdown]
# ### 4. mean()과 median()

# %% [markdown]
# ### 5. map()과 filter()

# %% [markdown]
# ### 6. enumerate()

# %% [markdown]
# ### 7. zip()

# %% [markdown]
# ### 8. sorted()

# %% [markdown]
# ### 9. min(), max()
