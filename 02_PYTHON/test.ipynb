# %%
def add(): pass

# %%
def minus(a, b):
    result = a - b
    return result

c=minus(2, 5)
d = c + 20
d
# Out:
# 27

# %%
def add(*nums): 
    return sum(nums)

add(10)
# Out:
# 10

# %%
add(10, 20)
# Out:
# 30

# %%
add(10, 20, 30)
# Out:
# 60

# %%
counter = 0

def increase():
    global counter
    counter += 1 # 전역 변수의 수치를 1씩 증가

def local_increase():
    counter = 100

increase()
increase()
local_increase()

# %%
numbers = [1, 2, 3, 4, 5]

# map(...) : [2, 3, 4, 5, 6]

result = list(filter(lambda x: x % 2 == 0, map(lambda x: x +1, numbers)))

result
# Out:
# [2, 4, 6]
