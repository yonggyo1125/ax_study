# %% [markdown]
# ## 5장 4강 : 이터레이터와 제너레이터

# %% [markdown]
# ### 1.이터러블(Iterable)

# %% [markdown]
# ### 2. 이터레이터(Iterator)

# %% [markdown]
# ### 3. 제너레이터(Generator)

# %% [markdown]
# ### 4. 제너레이터 표현식
