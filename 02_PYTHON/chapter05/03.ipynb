# %% [markdown]
# ## 5장 3강 : 클로저와 데코레이터

# %% [markdown]
# ### 1. 파이썬 함수의 일급 객체 특성과 고차 함수

# %% [markdown]
# ### 2 클로저(Closure)

# %% [markdown]
# - 고차 함수(Higher Order Function)

# %%
def outer():
    num1 = 10

    def inner():
        num2 = 20
        print(num1 + num2)

    return inner

inner = outer() # num1은 inner에 의해서 사용되므로 힙 영역에 생성되어 있음 
inner() # 10 + 20
# Out:
# 30

# %%
def add(num1):

    def _add(num2):

        def __add(num3):
            return num1 + num2 + num3

        return __add

    return _add

# %%
result1 = add(10)(20)(30)

result1
# Out:
# 60

# %%
add10 = add(10)

add10(30)(40)
# Out:
# 80

# %%
add10_20 = add(10)(20)

add10_20(30)
# Out:
# 60

# %% [markdown]
# ### 3. 데코레이터(Decorator)

# %% [markdown]
# - 디자인 패턴 중 한가지

# %%
def factorial1(num):
    result = 1

    for i in range(1, num + 1):
        result *= i

    return result

# %%
import time

start = time.time()

result = factorial1(10)
print(result)

end = time.time()
print("걸린 시간:", end - start)
# Out:
# 3628800
# 걸린 시간: 0.00020432472229003906

# %%
# 같은 함수 내에서 같은 함수를 반복해서 호출 하는 방법 - 재귀 함수(Recursive)
def factorial2(num):
    if (num < 1):
        return 1

    return num * factorial2(num - 1)

# %%
start = time.time() # 공통 기능

result = factorial2(10) # 핵심기능
print(result)

end = time.time() # 공통 기능 

print("걸린시간:", end - start)
# Out:
# 3628800
# 걸린시간: 0.0004489421844482422

# %%
import time

def time_checker(callback, num):
    start = time.time() # 공통 기능    

    result = callback(num) # 핵심 기능 - 팩토리얼 연산 함수(factorial1, factorial2)

    end = time.time() # 공통 기능
    print("걸린 시간:", end - start)

    return result

# %%
time_checker(factorial2, 10)
# Out:
# 걸린 시간: 4.5299530029296875e-06
# 3628800

# %%
import time

def time_check2(callback):
    def wrapper(*args, **kwargs):
        
        start = time.time() # 공통 기능

        result = callback(*args, **kwargs) # 핵심기능

        end = time.time() # 공통 기능
        print("걸린시간:", end - start)

        return result 
    
    return wrapper

# %%
@time_check2
def factorial2(num):
    if (num < 1):
        return 1

    return num * factorial2(num - 1)

# %%
factorial2(10)
# Out:
# 걸린시간: 2.1457672119140625e-06
# 걸린시간: 0.0003654956817626953
# 걸린시간: 0.00040268898010253906
# 걸린시간: 0.00042510032653808594
# 걸린시간: 0.0004425048828125
# 걸린시간: 0.00045943260192871094
# 걸린시간: 0.00047707557678222656
# 걸린시간: 0.0004949569702148438
# 걸린시간: 0.0005178451538085938
# 걸린시간: 0.0005352497100830078
# 걸린시간: 0.0007619857788085938
# 3628800

# %%
@time_check2
def add(num1, num2):
    return num1 + num2

# %%
add(num1=10, num2=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 add(num1=10, num2=20)
#
# TypeError: time_check2.<locals>.wrapper() got an unexpected keyword argument 'num1'

# %%
a = [10, 20]

def minus(num1, num2):
    return num1 - num2

minus(*a)
# Out:
# -10
