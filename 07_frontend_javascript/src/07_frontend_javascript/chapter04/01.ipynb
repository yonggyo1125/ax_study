// %% [markdown]
// ## 4장 1강 : JavaScript 개발 환경 구성

// %% [markdown]
// ### 1. 개발 환경 구축: 로컬 프로젝트 생성 및 Jupyter 커널 등록

// %% [markdown]
// #### 1.1 웹 브라우저도 자바스크립트 번역기입니다

// %% [markdown]
// #### 1.2 Node.js 설치 과정
// - Node.js (node)
// - NPM
// - NPX
// - NVM (Node Version Manager) 설치
//
// - 알아두면 유용한 주요 npm 명령어 및 옵션
//     - install / i
//     - uninstall / un
//     - --yes / -y
//     - --save-dev / -D
//     - --gloabl / -g

// %% [markdown]
// #### 1.3 로컬 프로젝트 생성 및 자바스크립트 커널 설치
// - tslab

// %%
var a = 100;
console.log(a)

// C:\\Users\\yonggyo\\AppData\\Local\\Author Software\\nvm\\installs\\v24.21.0\\node_modules\\tslab\\bin\\tslab
// Out:
// 100
